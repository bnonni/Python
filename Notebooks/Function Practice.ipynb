# %% [markdown]
# ## Practice

# %%
x = [1, 10, 20, 33, 456, 56, 11, 0, 1234, 9872, 9567, 768, 74, 90]
str = "Too small!"
def PullFromArray():
    for nums in x:
        if nums > 100:
            return x
        elif nums < 100:
            return x
        else:
            return str

PullFromArray()
# Out:
# [1, 10, 20, 33, 456, 56, 11, 0, 1234, 9872, 9567, 768, 74, 90]
