# %% [markdown]
# ## Pandas

# %% [markdown]
# #### Introduction to Pandas

# %%
import pandas as pd

# %%
data = pd.DataFrame({'Names': ['Sif', 'Daren', 'Bryan', 'Hector'],
                    'Dpt': ['Analytics', 'Media - SEM', 'Media - AFF', 'Analytics'],
                    'Years': [2, 2, 2, 1],
                    'Title': ['DS', 'MM', 'MM', 'Dr']})
# DataFrame function takes dictionary of keys and values to create a table

# %%
data
# Out:
#            Dpt   Names Title  Years
# 0    Analytics     Sif    DS      2
# 1  Media - SEM   Daren    MM      2
# 2  Media - AFF   Bryan    MM      2
# 3    Analytics  Hector    Dr      1

# %%
data.dtypes
# Out:
# Dpt      object
# Names    object
# Title    object
# Years     int64
# dtype: object

# %%
data.describe()
# Out:
#        Years
# count   4.00
# mean    1.75
# std     0.50
# min     1.00
# 25%     1.75
# 50%     2.00
# 75%     2.00
# max     2.00

# %%
data.columns
## .columns = argument
## .columns() = method
# Out:
# Index(['Dpt', 'Names', 'Title', 'Years'], dtype='object')

# %%
data.shape
# Out:
# (4, 4)

# %%
import pandas as pd

# %%
# Read the data.
data = pd.read_csv('titanic.csv')

# %%
# Checking information about the data. DO THIS EVERYTIME
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
# Rows and Columns
data.shape
# Out:
# (891, 12)

# %%
# Size, Rows x Columns
data.size
# Out:
# 10692

# %%
# Summary Statistics
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass  \
# count    891.000000  891.000000  891.000000
# unique          NaN         NaN         NaN
# top             NaN         NaN         NaN
# freq            NaN         NaN         NaN
# mean     446.000000    0.383838    2.308642
# std      257.353842    0.486592    0.836071
# min        1.000000    0.000000    1.000000
# 25%      223.500000    0.000000    2.000000
# 50%      446.000000    0.000000    3.000000
# 75%      668.500000    1.000000    3.000000
# max      891.000000    1.000000    3.000000
#
#                                                      Name   Sex         Age  \
# count                                                 891   891  714.000000
# unique                                                891     2         NaN
# top     Frauenthal, Mrs. Henry William (Clara Heinshei...  male         NaN
# freq                                                    1   577         NaN
# ...

# %%
# Top 5
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Bottom 10
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
### Slicing and Dicing

data['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
type(data['Name'])
# Out:
# pandas.core.series.Series

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# List Manipulation 
[1,2,3,5] * 4
# Out:
# [1, 2, 3, 5, 1, 2, 3, 5, 1, 2, 3, 5, 1, 2, 3, 5]

# %%
# Series Manipulation
data['Age'].head() * 4
# Out:
# 0     88.0
# 1    152.0
# 2    104.0
# 3    140.0
# 4    140.0
# Name: Age, dtype: float64

# %%
# this is a vector - becomes a matrix once you add a column
data['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
## Selecting Multiple ITems
data[ ['Name', 'Age']].head()
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
## Columns.

data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
## Drop columns 
print(data.columns)

#2 arguments, inplace=True 
data.drop(['PassengerId', 'Parch'], axis=1, inplace=True)

#
print(data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
## Drop columns 
print(data.columns)

#2 arguments, inplace=True 
data.drop(['Age'], axis=1)

#
print(data.columns)
data.head()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp            Ticket     Fare Cabin Embarked
# 0    male  22.0      1         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1          PC 17599  71.2833   C85        C
# 2  female  26.0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
## Above didn't delete Age because did not use inplace
## The Age attribute still exists but the data does not truly delete
## Drop columns 
print(data.columns)

#2 arguments, inplace=True 
data.drop(['Age'], axis=1, inplace=True)

#
print(data.columns)
data.head()
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Ticket', 'Fare', 'Cabin',
#        'Embarked'],
#       dtype='object')
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex  SibSp            Ticket     Fare Cabin Embarked
# 0    male      1         A/5 21171   7.2500   NaN        S
# 1  female      1          PC 17599  71.2833   C85        C
# 2  female      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
## ^Data above is missing Age, PassengerId and Parch

# %%
data[:5]
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex  SibSp            Ticket     Fare Cabin Embarked
# 0    male      1         A/5 21171   7.2500   NaN        S
# 1  female      1          PC 17599  71.2833   C85        C
# 2  female      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female      1            113803  53.1000  C123        S
# 4    male      0            373450   8.0500   NaN        S

# %%
data.name(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-233e15d3dfbc> in <module>()
# ----> 1 data.name(1)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
data = pd.read_csv('titanic.csv')

# %%
data.loc[[1][2]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-be20fad368b9> in <module>()
# ----> 1 data.loc[[1][2]]
#
# IndexError: list index out of range

# %%
data = pd.read_csv("Transaction Inquiries 02052018 (CSV).csv")

# %%
data.loc[0]['Order ID']
# Out:
# '6885794618'

# %%
data.head()
# Out:
#        Id      Order ID  Resolution Affiliate Reason Amount  \
# 0  170335    6885794618         NaN
# 1  170550  6450738992_1         NaN       NaN    NaN    NaN
# 2  173663    6193298295         NaN       NaN    NaN    NaN
# 3  173714    6982874438         NaN       NaN    NaN    NaN
# 4  173846    6584260939         NaN       NaN    NaN    NaN
#
#             Transaction Date                           Media Partner  \
# 0  2017-12-03T03:00:00-05:00                                Ebates .
# 1  2017-09-14T03:00:00-04:00  Upromise powered by Affinity Solutions
# 2  2017-12-05T03:00:00-05:00                        Clarus Commerce.
# 3  2017-12-19T03:00:00-05:00                                Ebates .
# 4  2017-12-31T03:00:00-05:00                                Ebates .
#
#    Sale Amount            Submission Date     ...       Unnamed: 13  \
# 0       784.40  2017-12-19T14:58:02-05:00     ...               NaN
# 1        29.99  2017-12-20T15:28:35-05:00     ...               NaN
# ...
