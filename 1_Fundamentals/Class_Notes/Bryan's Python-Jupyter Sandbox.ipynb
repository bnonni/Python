# %% [markdown]
# # First Program.

# %% [markdown]
# <markdown>This is markdown.</markdown>

# %%
def simpleAddition(x, y):
    
    return x + y

# %%
simpleAddition(4,5)
# Out:
# 9

# %%
result = simpleAddition(4,5)
result
# Out:
# 9

# %%
def Subtract(z, a):
    return z - a

# %%
Subtract(1000000000, 50000000000)
# Out:
# -49000000000

# %%
str = 'code'

# %%
def front_back(str):
    x = str
    return x

# %%
# Out:
#   File "<ipython-input-38-471ed61918b5>", line 1
#     return x
#             ^
# SyntaxError: 'return' outside function
