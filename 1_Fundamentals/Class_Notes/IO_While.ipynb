# %%
username = input("Provide Your Username: ")
username
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-1-fab8609e95ac> in <module>
# ----> 1 username = input("Provide Your Username: ")
#       2 username
#
# /usr/local/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     852         if not self._allow_stdin:
#     853             raise StdinNotImplementedError(
# --> 854                 "raw_input was called, but this frontend does not support input requests."
#     855             )
#     856         return self._input_request(str(prompt),
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %%
age = input("Enter Your Age: ")
type(age)
# Out:
# Enter Your Age: 27
# str

# %%
# We want age as int
age = input("What is your age? ")
age
print(type(age))
# Out:
# What is your age? 27
# <class 'str'>

# %%
## Test the evaluate function
age = eval(input("Age? ")) ##eval() takes a str & implements it as if it we're code (not a string)
print(age)
print(type(age))
# Out:
# Age? 27
# 27
# <class 'int'>

# %%
x = 5
eval("x + 1")
# Out:
# 6

# %%
name = "Bryan "
eval("name + 'Nonni'")
# Out:
# 'Bryan Nonni'

# %%
### While Loops
while True:
    x = input("Please enter your age: ")
    if eval(x) >= 21:
        print("Welcome to the Store! Here is our wine collection!")
    elif eval(x) >= 18 and eval(x) < 21:
        print("Hey, in a year or so, you can see this store!")
    elif eval(x) < 18:
        print("Hey! You are not supposed to be here!")
        break
# Out:
# Please enter your age: 12
# Hey! You are not supposed to be here!

# %% [markdown]
# ## File IO

# %%
##open() creates a new file or opens an existing file; the first str designates the file name, the 2nd designates the permission
test_file = open("sample.txt", "w")

# %%
## .name gives name of file attached to the variable
test_file.name
# Out:
# 'sample.txt'

# %%
## .encoding displays the way the file is encoded

test_file.encoding
# Out:
# 'cp1252'

# %%
open("sample.txt", "w")
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='w' encoding='cp1252'>

# %%
## ^io = a class, ^ name is the file name, ^ mode is the permissions, ^ encoding shows the format

# %%
## w+ = write + read; wb+ = writing + reading in binary; for all permissions go here: http://tutorialspoint.com/python/python_files_io.htm
comedians = open("comedians.txt", "w+")
comedians.write("Kevin Hart ")
comedians.write("Dave Chapelle ")
comedians.write("Romesh Ranganathan")
## must .close() the file otherwise it won't be saved
comedians.close()

# %%
names = ["Kevin", "Jimmy", "Dave", "Romesh"]
file = open("comedians.txt", "w")
file.writelines([ name + "\n" for name in names ])
file.close()

# %% [markdown]
# ## With

# %%
with open("comedians.txt", "r") as shit:
    for name in shit.readlines():
        print(name)
# Out:
# Kevin
#
# Jimmy
#
# Dave
#
# Romesh
