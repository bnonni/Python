# %% [markdown]
# # First Program.

# %% [markdown]
# <markdown>This is markdown.</markdown>

# %%
def simpleAddition(x, y):
    
    return x + y

# %%
simpleAddition(4,5)
# Out:
# 9

# %%
result = simpleAddition(4,5)
result
# Out:
# 9

# %%
def Subtract(z, a):
    return z - a
